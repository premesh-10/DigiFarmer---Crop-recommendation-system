# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# --- Basic Configuration ---
data_dir = 'dataset/soil_dataset'
img_height = 224
img_width = 224
batch_size = 32

# --- Load Training Data ---
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# --- Load Validation Data ---
validation_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Found the following classes:", class_names)
# Out:
# Found 656 files belonging to 8 classes.
# Using 591 files for training.
# Found 656 files belonging to 8 classes.
# Using 65 files for validation.
# Found the following classes: ['Alluvial Soil', 'Black Soil', 'Cinder Soil', 'Clay Soil', 'Laterite Soil', 'Peat Soil', 'Red Soil', 'Yellow Soil']

# %%
# --- Create a Data Augmentation Layer ---
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
    ]
)

# --- Configure the dataset for performance ---
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_ds = validation_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
preprocess_input = tf.keras.applications.resnet50.preprocess_input

# --- Load the pre-trained ResNet50 model ---
base_model = tf.keras.applications.ResNet50(
    input_shape=(img_height, img_width, 3),
    include_top=False,
    weights='imagenet'
)

# --- Freeze the base model ---
base_model.trainable = False

# --- Build the full model ---
inputs = keras.Input(shape=(img_height, img_width, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model = keras.Model(inputs, outputs)

# --- Print a summary of the model architecture ---
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 224, 224,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 224, 224,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ add[0][0]         │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │     16,392 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,604,104 (90.04 MB)
#  Trainable params: 16,392 (64.03 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# --- Compile the model ---
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.01),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# --- Train the model ---
epochs = 50
history = model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs
)
# Out:
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.5939 - loss: 1.7815 - val_accuracy: 0.6769 - val_loss: 1.0288
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.8206 - loss: 0.6757 - val_accuracy: 0.8615 - val_loss: 0.6898
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8883 - loss: 0.3458 - val_accuracy: 0.8308 - val_loss: 1.0599
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9120 - loss: 0.3164 - val_accuracy: 0.7692 - val_loss: 1.0879
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9002 - loss: 0.3559 - val_accuracy: 0.8615 - val_loss: 0.8213
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9425 - loss: 0.1822 - val_accuracy: 0.8462 - val_loss: 0.7692
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9340 - loss: 0.2188 - val_accuracy: 0.8308 - val_loss: 0.8906
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9323 - loss: 0.2222 - val_accuracy: 0.7231 - val_loss: 1.7556
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9323 - loss: 0.2183 - val_accuracy: 0.7538 - val_loss: 1.2545
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9374 - loss: 0.1835 - val_accuracy: 0.8154 - val_loss: 1.1492
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9391 - loss: 0.2362 - val_accuracy: 0.7846 - val_loss: 1.4012
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9239 - loss: 0.2702 - val_accuracy: 0.8000 - val_loss: 1.3290
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.9188 - loss: 0.3105 - val_accuracy: 0.8308 - val_loss: 1.0982
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9459 - loss: 0.2216 - val_accuracy: 0.8308 - val_loss: 1.6569
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9492 - loss: 0.2182 - val_accuracy: 0.7077 - val_loss: 2.1204
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.9442 - loss: 0.1941 - val_accuracy: 0.7846 - val_loss: 1.7754
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.9340 - loss: 0.2463 - val_accuracy: 0.8000 - val_loss: 1.1056
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9560 - loss: 0.1532 - val_accuracy: 0.8308 - val_loss: 1.0848
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9560 - loss: 0.1800 - val_accuracy: 0.8154 - val_loss: 1.3018
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9475 - loss: 0.2128 - val_accuracy: 0.8000 - val_loss: 1.7409
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9492 - loss: 0.2165 - val_accuracy: 0.8615 - val_loss: 1.2337
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9492 - loss: 0.1744 - val_accuracy: 0.6615 - val_loss: 2.6101
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9188 - loss: 0.3765 - val_accuracy: 0.7385 - val_loss: 2.2961
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9289 - loss: 0.2821 - val_accuracy: 0.8308 - val_loss: 1.8074
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9391 - loss: 0.2701 - val_accuracy: 0.8154 - val_loss: 1.8419
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9323 - loss: 0.3533 - val_accuracy: 0.8000 - val_loss: 1.7655
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9509 - loss: 0.1930 - val_accuracy: 0.8462 - val_loss: 1.5541
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9492 - loss: 0.2652 - val_accuracy: 0.8462 - val_loss: 1.2450
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9526 - loss: 0.2078 - val_accuracy: 0.7077 - val_loss: 3.3390
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9577 - loss: 0.2046 - val_accuracy: 0.8154 - val_loss: 1.5885
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9526 - loss: 0.2328 - val_accuracy: 0.7846 - val_loss: 2.1903
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9611 - loss: 0.1527 - val_accuracy: 0.7846 - val_loss: 1.9539
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9695 - loss: 0.1290 - val_accuracy: 0.8308 - val_loss: 1.4854
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.9594 - loss: 0.1210 - val_accuracy: 0.8462 - val_loss: 1.6633
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9611 - loss: 0.1713 - val_accuracy: 0.7385 - val_loss: 2.7787
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9729 - loss: 0.0793 - val_accuracy: 0.8154 - val_loss: 1.7381
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9679 - loss: 0.1531 - val_accuracy: 0.7538 - val_loss: 2.2306
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9594 - loss: 0.1404 - val_accuracy: 0.8154 - val_loss: 1.8644
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9662 - loss: 0.1137 - val_accuracy: 0.7538 - val_loss: 2.1051
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9645 - loss: 0.1816 - val_accuracy: 0.8308 - val_loss: 2.2101
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9645 - loss: 0.2135 - val_accuracy: 0.8462 - val_loss: 1.9510
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9594 - loss: 0.2427 - val_accuracy: 0.7538 - val_loss: 2.4124
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.9475 - loss: 0.3290 - val_accuracy: 0.8154 - val_loss: 2.4501
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.9679 - loss: 0.1695 - val_accuracy: 0.8154 - val_loss: 2.0067
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9577 - loss: 0.2320 - val_accuracy: 0.8154 - val_loss: 2.1093
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9492 - loss: 0.2502 - val_accuracy: 0.8462 - val_loss: 2.5118
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9662 - loss: 0.1582 - val_accuracy: 0.8000 - val_loss: 2.6908
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9611 - loss: 0.2290 - val_accuracy: 0.7846 - val_loss: 3.1145
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9645 - loss: 0.1613 - val_accuracy: 0.8308 - val_loss: 2.1227
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9679 - loss: 0.0823 - val_accuracy: 0.7692 - val_loss: 2.8182

# %%
# --- Get Model Accuracy ---
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]
print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Validation Accuracy: {val_acc:.4f}")
